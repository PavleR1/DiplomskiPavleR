# %%
import pandas as pd
import time
from nba_api.stats.static import players
from nba_api.stats.endpoints import playercareerstats,commonplayerinfo

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
nba_players = players.get_players()

# %%
nba_players_df = pd.DataFrame(data=nba_players)
nba_players_df
# Out:
#            id            full_name first_name     last_name  is_active
# 0       76001       Alaa Abdelnaby       Alaa     Abdelnaby      False
# 1       76002      Zaid Abdul-Aziz       Zaid    Abdul-Aziz      False
# 2       76003  Kareem Abdul-Jabbar     Kareem  Abdul-Jabbar      False
# 3          51   Mahmoud Abdul-Rauf    Mahmoud    Abdul-Rauf      False
# 4        1505    Tariq Abdul-Wahad      Tariq   Abdul-Wahad      False
# ...       ...                  ...        ...           ...        ...
# 4718  1627790           Ante Zizic       Ante         Zizic      False
# 4719    78647             Jim Zoet        Jim          Zoet      False
# 4720    78648            Bill Zopf       Bill          Zopf      False
# 4721  1627826          Ivica Zubac      Ivica         Zubac       True
# 4722    78650           Matt Zunic       Matt         Zunic      False
#
# [4723 rows x 5 columns]

# %%
nba_players_id = [x['id'] for x in nba_players]

# %%
players_df = pd.DataFrame()
players_df = players_df.append(playercareerstats.PlayerCareerStats(player_id=nba_players_id[0]).get_data_frames()[0])

# %%
i = 0
for x in range(0,len(nba_players_id)):
    players_df = players_df.append(playercareerstats.PlayerCareerStats(player_id=nba_players_id[x]).get_data_frames()[0])
    if i ==40:
        time.sleep(10)
        i=0
    else:
        i+=1

# %%
players_df
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION PLAYER_AGE  GP  \
# 0      76001   1990-91        00  1610612757               POR       23.0  43
# 1      76001   1991-92        00  1610612757               POR       24.0  71
# 2      76001   1992-93        00  1610612749               MIL       25.0  12
# 3      76001   1992-93        00  1610612738               BOS       25.0  63
# 4      76001   1992-93        00           0               TOT       25.0  75
# ..       ...       ...       ...         ...               ...        ...  ..
# 4    1627826   2018-19        00           0               TOT       22.0  59
# 5    1627826   2019-20        00  1610612746               LAC       23.0  72
# 6    1627826   2020-21        00  1610612746               LAC       24.0  72
# 7    1627826   2021-22        00  1610612746               LAC       25.0  76
# 0      78650   1948-49        00  1610610036               WAS       29.0  56
#
# ...

# %%
common_players_df = commonplayerinfo.CommonPlayerInfo(player_id=nba_players_id[0]).get_data_frames()[0]

# %%
i=0
for x in range(0,len(nba_players_id)):
    common_players_df = common_players_df.append(commonplayerinfo.CommonPlayerInfo(player_id=nba_players_id[x]).get_data_frames()[0])
    if i ==20:
        time.sleep(10)
        i=0
    else:
        i+=1

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
commonplayerinfo.CommonPlayerInfo(player_id=2431).get_data_frames()[0]
# Out:
#    PERSON_ID FIRST_NAME LAST_NAME DISPLAY_FIRST_LAST DISPLAY_LAST_COMMA_FIRST  \
# 0       2431      David  Andersen     David Andersen          Andersen, David
#
#   DISPLAY_FI_LAST     PLAYER_SLUG            BIRTHDATE        SCHOOL  \
# 0     D. Andersen  david-andersen  1980-06-23T00:00:00  FC Barcelona
#
#      COUNTRY        LAST_AFFILIATION HEIGHT WEIGHT  SEASON_EXP JERSEY  \
# 0  Australia  FC Barcelona/Australia                        20
#
#   POSITION ROSTERSTATUS GAMES_PLAYED_CURRENT_SEASON_FLAG  TEAM_ID TEAM_NAME  \
# 0              Inactive                                N        0
#
#   TEAM_ABBREVIATION TEAM_CODE TEAM_CITY      PLAYERCODE  FROM_YEAR  TO_YEAR  \
# 0                                        david_andersen       2009     2017
#
#   DLEAGUE_FLAG NBA_FLAG GAMES_PLAYED_FLAG DRAFT_YEAR DRAFT_ROUND DRAFT_NUMBER  \
# 0            N        Y                 Y       2002           2           36
#
#   GREATEST_75_FLAG
# 0                N

# %%
players_df = players_df.merge(nba_players_df,left_on='PLAYER_ID',right_on='id')

# %%
players_df.head()
# Out:
#   PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION PLAYER_AGE  GP  \
# 0     76001   1990-91        00  1610612757               POR       23.0  43
# 1     76001   1991-92        00  1610612757               POR       24.0  71
# 2     76001   1992-93        00  1610612749               MIL       25.0  12
# 3     76001   1992-93        00  1610612738               BOS       25.0  63
# 4     76001   1992-93        00           0               TOT       25.0  75
#
#    GS     MIN  FGM  FGA FG_PCT FG3M FG3A FG3_PCT FTM  FTA FT_PCT   OREB  \
# 0   0   290.0   55  116  0.474    0    0     0.0  25   44  0.568   27.0
# 1   1   934.0  178  361  0.493    0    0     0.0  76  101  0.752   81.0
# 2   0   159.0   26   56  0.464    0    1     0.0  12   16   0.75   12.0
# 3  52  1152.0  219  417  0.525    0    0     0.0  76  100   0.76  114.0
# 4  52  1311.0  245  473  0.518    0    1     0.0  88  116  0.759  126.0
#
# ...

# %%
players_df = players_df.drop(['id','first_name','last_name'],1)

# %%
common_players_df.to_csv('Common_Nba_Players.csv')

# %%
players_df.to_csv('NBA_PLAYERS.csv')
